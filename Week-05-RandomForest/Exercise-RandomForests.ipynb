# %%
# Import our libraries 

# Pandas and numpy for data wrangling
import pandas as pd
import numpy as np

# Seaborn / matplotlib for visualization 
import matplotlib as plt
import seaborn as sns
sns.set()

# Import the trees from sklearn
from sklearn import tree

# Helper function to split our data
from sklearn.model_selection import train_test_split


# Helper fuctions to evaluate our model.
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, f1_score, roc_auc_score


# Helper function for hyper-parameter turning.
from sklearn.model_selection import GridSearchCV


# Import our Decision Tree
from sklearn.tree import DecisionTreeClassifier

# Import our Random Forest 
from sklearn.ensemble import RandomForestClassifier

# Library for visualizing our tree
# If you get an error, run 'conda install python-graphviz' in your terminal (without the quotes).
import graphviz 

# Use inline so our visualizations display in notebook
# %matplotlib inline

# %% [markdown]
# ## Main Steps when building a Machine Learning Model.
# 1. Inspect and explore data.
# 2. Select and engineer features.
# 3. Build and train model.
# 4. Evaluate model.

# %% [markdown]
# # #1 Inspect and explore data.
# * Load titanic data
# * Visualize all the data using sns.pairplot
# * Check for null values

# %%
# Load in the titanic data set.
df = pd.read_csv("data/titanic.csv")
df.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Visualize all the data using sns.pairplot
sns.pairplot(df)

# %%
# Check for null values
df.isnull().sum()
# Out:
# passengerid      0
# survived         0
# pclass           0
# name             0
# sex              0
# age            177
# sibsp            0
# parch            0
# ticket           0
# fare             0
# cabin          687
# embarked         2
# dtype: int64

# %% [markdown]
# # #2 Select and engineer features.
# 1. Fill age null values with -999
# 1. Convert to numerical values if need be by using `pd.get_dummies()`
# 1. Create a list of the features you are going to use.  In this case use as many or as little as you would like.
# 1. Define our `X` and `y`
# 1. Split our data into trainig and testing sets.

# %%
# Fill age null values with -999
print(df['age'].isnull().sum())

df['age'].fillna(-999, inplace=True)

print(df['age'].isnull().sum())
# Out:
# 177
# 0

# %%
# 1. Convert to numerical values if need be by using `pd.get_dummies()`
df = pd.get_dummies(data=df, columns=['pclass', 'sex', 'embarked'], drop_first=True)
df.head()
# Out:
#    passengerid  survived                                               name  \
# 0            1         0                            Braund, Mr. Owen Harris
# 1            2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3         1                             Heikkinen, Miss. Laina
# 3            4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5         0                           Allen, Mr. William Henry
#
#     age  sibsp  parch            ticket     fare cabin  pclass_2  pclass_3  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN         0         1
# 1  38.0      1      0          PC 17599  71.2833   C85         0         0
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN         0         1
# 3  35.0      1      0            113803  53.1000  C123         0         0
# 4  35.0      0      0            373450   8.0500   NaN         0         1
#
#    sex_male  embarked_Q  embarked_S
# 0         1           0           1
# 1         0           0           0
# 2         0           0           1
# 3         0           0           1
# 4         1           0           1

# %%
# 2. Create a list of the features we are going to use.
selected_features = list(df.columns)
remove_cols = ['survived', 'name', 'passengerid', 'ticket', 'cabin']

selected_features = [feature for feature in selected_features if feature not in remove_cols]

print(selected_features)
# Out:
# ['age', 'sibsp', 'parch', 'fare', 'pclass_2', 'pclass_3', 'sex_male', 'embarked_Q', 'embarked_S']

# %%
# Define our `X` and `y`
X = df[selected_features]

y = df['survived']

# %%
# Split our data into trainig and testing sets.

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=45)

print('Length of our Training data:', X_train.shape, '\nLength of our Testing data:', X_test.shape)
# Out:
# Length of our Training data: (712, 9)
# Length of our Testing data: (179, 9)

# %% [markdown]
# # #3 Build and train model.
# 1. For our first pass, initialize our model with `max_depth=2`.
# 2. Fit our model with our training data.
# 3. Make predictions of our testing data.
# 4. Evaluate and print our model scores using accuracy, precision, recall, f1 scores, and auc scores.
#     * To calculate auc score you have to get the predicted probabilites for the Survived class using `model.predict_proba(X_test)[:,1]`
# 5. Visualize our Decision Tree using provided code.

# %%
# For our first pass, initialize our model with `max_depth=2`.

model = DecisionTreeClassifier(max_depth=2)

# %%
# Fit our model with our training data. 
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
# Make predictions of our testing data. 
y_pred = model.predict(X_test)

# %%
# 4. Evaluate and print our model scores using accuracy, precision, recall, f1 scores, and auc scores. 
accuracy = accuracy_score(y_true=y_test, y_pred=y_pred)
print("Accuracy Score: %f" % accuracy)

precision = precision_score(y_true=y_test, y_pred=y_pred)
print("Precision Score: %f" % precision)

recall = recall_score(y_true=y_test, y_pred=y_pred)
print("Recall Score: %f" % recall)

f1 = f1_score(y_true=y_test, y_pred=y_pred)
print('F1 Score: %f' % f1)

# Calculate predicted probabilities
y_pred_proba = model.predict_proba(X_test)

# Keep only the proba for True
y_pred_proba = y_pred_proba[:,1]

# Compute auc score
auc = roc_auc_score(y_true=y_test, y_score=y_pred_proba)
print('AUC Score: %f' % auc)
# Out:
# Accuracy Score: 0.832402
# Precision Score: 0.750000
# Recall Score: 0.774194
# F1 Score: 0.761905
# AUC Score: 0.868004

# %% [markdown]
# # OPTIONAL:  Visualize your decision tree.
# * If you get an error, you may need to install the graphviz library.
# * Run this command in your terminal to install the graphviz library.
#     * `conda install python-graphviz`
# * If that does not work, then try installing the library using pip.
#     * `pip install graphviz`
#
# * If neither of those work, you can just skip this step.

# %%
# OPTIONAL 
# Visualize your decision tree. 
dot_data = tree.export_graphviz(model, out_file=None, 
                     feature_names=selected_features,
                     class_names=['died','survived'],
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %% [markdown]
# # Picking the right parameters...

# %% [markdown]
# # Parameter tuning of your Decision Tree using GridSearch
#
# 1. Make a dictionary of at least 3 parameters and a list of 3 values for each for your grid search.
# 1. Initalize your GridSearchCV with a DecisionTreeClassifier, your param_grid, and what you are optimizing for.  Choose any of the five optimization strategies; accuracy, precision, recall, f1, or roc_auc.
# 1. Fit your GridSearchCV with your training data.
# 1. Print the parameters of your best model.
# 1. Evaluate your best model using accuracy, precision, recall, f1 scores, and auc scores.
# 1. Visualize your best tree.
# 1. Which feature was your most important feature?
#
# ```python
# tree.DecisionTreeClassifier(
#     *,
#     criterion='gini',
#     splitter='best',
#     max_depth=None,
#     min_samples_split=2,
#     min_samples_leaf=1,
#     min_weight_fraction_leaf=0.0,
#     max_features=None,
#     random_state=None,
#     max_leaf_nodes=None,
#     min_impurity_decrease=0.0,
#     min_impurity_split=None,
#     class_weight=None,
#     presort='deprecated',
#     ccp_alpha=0.0,
# )
# ```

# %% [markdown]
# [Tips on how to customize / set the paramters in the decision tree.](https://scikit-learn.org/stable/modules/tree.html#tips-on-practical-use)

# %%
# 1. Make a dictionary of at least 3 parameters and a list of 3 values for each for your grid search.from sklearn.model_selection import GridSearchCV
params = { 
    'max_depth': range(5,15,5),
    'min_samples_split': range(10,30,10),
    'max_leaf_nodes': [20,40,None]
}

# %%
# 1. Initalize your GridSearchCV with a DecisionTreeClassifier, your param_grid, and what you are optimizing for.  Choose any of the five optimization strategies; accuracy, precision, recall, f1, or roc_auc.
grid_search_cv =  GridSearchCV(estimator=DecisionTreeClassifier(), param_grid=params, scoring='roc_auc')

# %%
# 1. Fit your GridSearchCV with your training data. 
grid_search_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': range(5, 15, 5),
#                          'max_leaf_nodes': [20, 40, None],
#                          'min_samples_split': range(10, 30, 10)},
#              scoring='roc_auc')

# %%
# 1. Print the parameters of your best model. 
# Print the best parameters it found
print( grid_search_cv.best_params_ )
# Out:
# {'max_depth': 5, 'max_leaf_nodes': 40, 'min_samples_split': 20}

# %%
# 1. Evaluate your best model using accuracy, precision, recall, f1 scores, and auc scores. 

# This command gives you the best tree
model = grid_search_cv.best_estimator_

# Now lets evaluate our model
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_true=y_test, y_pred=y_pred)
print("Accuracy Score: %f" % accuracy)

precision = precision_score(y_true=y_test, y_pred=y_pred)
print("Precision Score: %f" % precision)

recall = recall_score(y_true=y_test, y_pred=y_pred)
print("Recall Score: %f" % recall)

f1 = f1_score(y_true=y_test, y_pred=y_pred)
print('F1 Score: %f' % f1)

# Calculate predicted probabilities, keep only probability for when class = 1
y_pred_proba = model.predict_proba(X_test)[:,1]
auc = roc_auc_score(y_true=y_test, y_score=y_pred_proba)
print('AUC Score: %f' % auc)
# Out:
# Accuracy Score: 0.877095
# Precision Score: 0.870370
# Recall Score: 0.758065
# F1 Score: 0.810345
# AUC Score: 0.895988

# %%
# OPTIONAL!

# 1. Visualize your best tree
dot_data = tree.export_graphviz(model, out_file=None, 
                     feature_names=selected_features,
                     class_names=['died','survived'],
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %%
# 1. Which feature was your most important feature?
# Now lets look at our feature importances
feature_imp = pd.DataFrame.from_dict( {'feature_importance': model.feature_importances_,
                                       'feature':selected_features }).sort_values('feature_importance', ascending=False)
feature_imp
# Out:
#    feature_importance     feature
# 6            0.533159    sex_male
# 3            0.176732        fare
# 5            0.125354    pclass_3
# 0            0.087040         age
# 2            0.038031       parch
# 1            0.020964       sibsp
# 7            0.018720  embarked_Q
# 4            0.000000    pclass_2
# 8            0.000000  embarked_S

# %% [markdown]
# # Now onto Random Forests...
# Were going to do the same with, but this time with a random forest. Remeber... Repetition is the father of learning.
#
# 1. Make a dictionary of at least 3 parameters and a list of 3 values for each for your grid search.
# 1. Initalize your GridSearchCV with a RandomForestClassifer, your param_grid, and what you are optimizing for.  Choose any of the five optimization strategies; accuracy, precision, recall, f1, or roc_auc.
# 1. Fit your GridSearchCV with your training data.
# 1. Print the parameters of your best model.
# 1. Evaluate your best model using accuracy, precision, recall, f1 scores, and auc scores.
# 1. Which feature was your most important feature?

# %% [markdown]
# # Parameters of the Random Forest Classifier

# %% [markdown]
# ```python
# RandomForestClassifier(
#     n_estimators=100,
#     *,
#     criterion='gini',
#     max_depth=None,
#     min_samples_split=2,
#     min_samples_leaf=1,
#     min_weight_fraction_leaf=0.0,
#     max_features='auto',
#     max_leaf_nodes=None,
#     min_impurity_decrease=0.0,
#     min_impurity_split=None,
#     bootstrap=True,
#     oob_score=False,
#     n_jobs=None,
#     random_state=None,
#     verbose=0,
#     warm_start=False,
#     class_weight=None,
#     ccp_alpha=0.0,
#     max_samples=None,
# )
# ```

# %%
# 1. Make a dictionary of at least 3 parameters and a list of 3 values for each for your grid search. 
params = { 
    'max_depth': range(5,15,5),
    'min_samples_split': range(10,30,10),
    'max_leaf_nodes': [20,40,None]
}

# %%
# 1. Initalize your GridSearchCV with a RandomForestClassifer, your param_grid, and what you are optimizing for.  Choose any of the five optimization strategies; accuracy, precision, recall, f1, or roc_auc.

grid_search_cv = GridSearchCV(estimator=RandomForestClassifier(), param_grid=params, scoring='roc_auc')

# %%
# 1. Fit your GridSearchCV with your training data. 
grid_search_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'max_depth': range(5, 15, 5),
#                          'max_leaf_nodes': [20, 40, None],
#                          'min_samples_split': range(10, 30, 10)},
#              scoring='roc_auc')

# %%
# 1. Print the parameters of your best model. 
# Print the best parameters it found
print(grid_search_cv.best_params_)
# Out:
# {'max_depth': 5, 'max_leaf_nodes': 20, 'min_samples_split': 10}

# %%
# 1. Evaluate your best model using accuracy, precision, recall, f1 scores, and auc scores. 

# This command gives you tree that has the highest f1-score. 
model = grid_search_cv.best_estimator_

# Now lets evaluate our model
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_true=y_test, y_pred=y_pred)
print("Accuracy Score: %f" % accuracy)

precision = precision_score(y_true=y_test, y_pred=y_pred)
print("Precision Score: %f" % precision)

recall = recall_score(y_true=y_test, y_pred=y_pred)
print("Recall Score: %f" % recall)

f1 = f1_score(y_true=y_test, y_pred=y_pred)
print('F1 Score: %f' % f1)

# Calculate predicted probabilities, keep only probability for when class = 1
y_pred_proba = model.predict_proba(X_test)[:,1]
auc = roc_auc_score(y_true=y_test, y_score=y_pred_proba)
print('AUC Score: %f' % auc)
# Out:
# Accuracy Score: 0.871508
# Precision Score: 0.830508
# Recall Score: 0.790323
# F1 Score: 0.809917
# AUC Score: 0.904260

# %%
# 1. Which feature was your most important feature?
# Now lets look at our feature importances
feature_imp = pd.Series(model.feature_importances_,index=selected_features).sort_values(ascending=False)
feature_imp
# Out:
# sex_male      0.479048
# fare          0.188219
# pclass_3      0.110271
# age           0.087417
# parch         0.043010
# sibsp         0.039895
# pclass_2      0.018183
# embarked_Q    0.017275
# embarked_S    0.016682
# dtype: float64

# %% [markdown]
# # Build a random forest using the ny-vs-sf-housing.csv data.
# * Your target variable, aka the column you are trying to predict, aka your `y` variable is `in_sf`.
# * Can you get an accuracy above 91%?
# * What was your most important feature?

# %%
df = pd.read_csv('data/ny-vs-sf-houses.csv')
df.head()
# Out:
#    in_sf  beds  bath    price  year_built  sqft  price_per_sqft  elevation
# 0      0   2.0   1.0   999000        1960  1000             999         10
# 1      0   2.0   2.0  2750000        2006  1418            1939          0
# 2      0   2.0   2.0  1350000        1900  2150             628          9
# 3      0   1.0   1.0   629000        1903   500            1258          9
# 4      0   0.0   1.0   439000        1930   500             878         10

# %%
df.describe().round(2)
# Out:
#         in_sf    beds    bath        price  year_built     sqft  \
# count  492.00  492.00  492.00       492.00      492.00   492.00
# mean     0.54    2.16    1.91   2020696.04     1959.10  1522.99
# std      0.50    1.31    1.07   2824054.58       40.58  1014.37
# min      0.00    0.00    1.00    187518.00     1880.00   310.00
# 25%      0.00    1.00    1.00    749000.00     1924.00   832.75
# 50%      1.00    2.00    2.00   1145000.00     1960.00  1312.00
# 75%      1.00    3.00    2.00   1908750.00     2001.00  1809.00
# max      1.00   10.00   10.00  27500000.00     2016.00  7800.00
#
#        price_per_sqft  elevation
# count          492.00     492.00
# mean          1195.63      39.85
# std            733.77      44.67
# min            270.00       0.00
# 25%            730.50      10.00
# 50%            960.00      18.50
# 75%           1419.00      61.00
# max           4601.00     238.00

# %%
# BUILD, TRAIN, AND EVAULATE A RANDOM FOREST MODEL BELOW. 

df.isnull().sum()
# Out:
# in_sf             0
# beds              0
# bath              0
# price             0
# year_built        0
# sqft              0
# price_per_sqft    0
# elevation         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 33

# %%
print(df.shape)
df.drop_duplicates(inplace=True)
print(df.shape)
# Out:
# (492, 8)
# (459, 8)

# %%
sns.pairplot(df)

# %%
selected_features = list(df.columns)
selected_features.remove('in_sf')
print(selected_features)
# Out:
# ['beds', 'bath', 'price', 'year_built', 'sqft', 'price_per_sqft', 'elevation']

# %%
X = df[selected_features]
y = df['in_sf']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=45)

print(f'Length of our Training data: {X_train.shape} \nLength of our Testing data: {X_test.shape}')
# Out:
# Length of our Training data: (367, 7)
# Length of our Testing data: (92, 7)

# %%
# please DO NOT re-run this, it takes a long time
params = { 
    'n_estimators': range(5,15,2),
    'criterion': ['gini', 'entropy'],
    'max_depth': range(3,18,3),
    'min_samples_split': range(5,25,5),
    'max_leaf_nodes': [10,20,None],
    'max_features': [2,4,'auto']
}

grid_search_cv = GridSearchCV(estimator=RandomForestClassifier(), param_grid=params, scoring='roc_auc')

grid_search_cv.fit(X_train, y_train)

print(grid_search_cv.best_params_)
# Out:
# {'criterion': 'gini', 'max_depth': 12, 'max_features': 4, 'max_leaf_nodes': None, 'min_samples_split': 5, 'n_estimators': 13}

# %%
model = grid_search_cv.best_estimator_

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_true=y_test, y_pred=y_pred)
print("Accuracy Score: %f" % accuracy)

precision = precision_score(y_true=y_test, y_pred=y_pred)
print("Precision Score: %f" % precision)

recall = recall_score(y_true=y_test, y_pred=y_pred)
print("Recall Score: %f" % recall)

f1 = f1_score(y_true=y_test, y_pred=y_pred)
print('F1 Score: %f' % f1)

y_pred_proba = model.predict_proba(X_test)[:,1]
auc = roc_auc_score(y_true=y_test, y_score=y_pred_proba)
print('AUC Score: %f' % auc)
# Out:
# Accuracy Score: 0.913043
# Precision Score: 0.977273
# Recall Score: 0.860000
# F1 Score: 0.914894
# AUC Score: 0.954048

# %%
feature_imp = pd.Series(model.feature_importances_,index=selected_features).sort_values(ascending=False)
feature_imp
# Out:
# elevation         0.423205
# price_per_sqft    0.254981
# year_built        0.124152
# sqft              0.097144
# price             0.068820
# beds              0.015892
# bath              0.015806
# dtype: float64
